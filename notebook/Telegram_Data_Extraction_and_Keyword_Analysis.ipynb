# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

from data_cleaning.telegram_data_extraction import TelegramDataExtractor

# Set the file path
file_path = '../data_collection/raw_data/messages.csv'

# Create an instance of TelegramDataExtractor
extractor = TelegramDataExtractor(file_path)

# Load the data
extractor.load_data()

# Display the first few rows of the dataframe
extractor.display_data()

# Clean the text
extractor.clean_text()
# Out:
# Data loaded successfully.
#                              message_id      sender_id  \
# 0  0f06547f-dc47-4c78-b7f2-85c7eec347bd -1001102021238
# 1  cd19100c-85b4-4585-9b45-8f7ae125e0ee -1001102021238
# 2  ac45648c-dd0a-4a67-a39f-01d812a2cd6b -1001102021238
# 3  9986431b-48fc-473b-896e-fc54c3baf063 -1001102021238
# 4  84c91958-f637-41ec-af21-d7acae3de912 -1001102021238
#
#                                         message_text    channel
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...  DoctorsET
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...  DoctorsET
# 2  ሞት በስኳር \r\n\r\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን...  DoctorsET
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\r\n\...  DoctorsET
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...  DoctorsET
# Text cleaned successfully.
# '👈👈 በቀን አንዴ ብቻ የሚባለው የቢዝነስ አማካሪ በ 10000 ብር ብቻ የተጀመረ ቢዝነስ እስከ ሚሊየኖች ያየገው የፕራግማ ኢንቨስትመንት መስራች መርድ ብስራት ብላክ ማርኬት ዋጋ ማነው ሚተምነው ኢትዮጵያ ውስጥ ቢዝነስ ለመጀመር ጥሩ ሰአት ነው ወይ 3 ቢዝነስ ስንጀምር የምንሰራው ስህተቶች አሁኑኑ ይመልከተቱ 👇👇 ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከፋተኛ ዝግጅት በማድረግ ላይ ይገኛል ። ዩሃንስ ግርማ ጆኒ በ ቲክቶክ ከ 500000 በላይ ተከታይ ያገኘው ከ አሜሪካ ወደ ኢትዮጵያ ገንዳ ውስጥ ከመተኛት እስከ ከፋተኛ ተከፋይ በኢትዮጵያ 1 take production በመባል የሚታወቀው ዩሃንስ ግርማ ጆኒ ከዲፕሬሽን እስከ ታዋቂነትን ያተረፈው ጆኒ አሁኑኑ ይመልከቱ 👇 ሞት በስኳር ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ይሆን የታሸገ ትክክለኛ ጁስ ኢትዮጵያ ውስጥ የለም ሁሉም ወላጅ ሊያየው የሚገባ የታሸጉ ጁሶች መጠጣት እራስን ለከፍተኛ ጉዳት እስከ ሞት ድረስ ማጋለጥ ነው ለሁሉም ኢኮኖሚ ጤናንም የሚጠብቅ አመጋገብ የቱ ነው ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ፈውስ እና ህክምና ሙሉ ቪዲዮውን ተመልክተው ሃሳብ አስተያየቶን ያካፍሉን 👇👇👇👇 በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ Homosexuality ግብረ ሰዶም በተለያዩ ቦታዎች ላይ እየታየ ይገኛል ይህም አጥብቀን ምንቃወመው ጉዳይ ሲሆን ይህ ችግር በህምና ይለያል ወይ ቅድመ ምልክት አለው ወይ ወላጆች ልጆቻችሁን እንዴት መጠበቅ ትችላለቹ ህክምናስ አለው ወይ በምንመገበው ምግብ ሊቀይሩየን ይችላሉ ወይ አሁኑኑ ገብተው ሙሉ ቪዲዮውን ይመልከቱ 👇👇👇👇👇👇 ዶክተርስ ኢትዮጽያ በአዲስ ፕሮገራም ጀመረ ማረጥ ሜኖፖዝ ጋር ተያይዞ የሚመጣ ሴቶች ላይ የሚከሰት የጤና ችግሮች ሴቶች ላይ የሚከሰት የ ግብረስጋ ግንኙነት ስሜት መቀነስ የሴቶች የወር አበባ ግዜ እና ሌሎችም ጉዳዮች ተነስተዋል አሁኑኑ ይመልከቱ ከ ቴሌቪዥን ፕሮግራሞቻችን በተጨማሪ አዲስ በልዩ አቀራረብ ይበልጥ የናንተን የተመልካች ጥያቄ ለመመለስ ይህን የመሰለ ፕሮግራም ይዘን መተናል የጤና ጥያቄዎን ለመላክ doctorsEt ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው እነዚህን እንቅስቃሴዎች በማድረግ በ አጭር ግዜ ውስጥ ለውጥ ማምጣት ይችላሉ እቤትዎ ሆነው ጠዎት ወይንም ማታ ላይ በ 5 ደቃቃ ውስጥ ብቻ የጎን ቦርጭስብ ለማጥፋት ቀንዎን በንቃት ለመጀመር እነዚህን እንቅስቃሴዎች ያድርጉ ለሁሉም እድሜ ክልል የሚሆን እንቅስቃሴ ስለሆነ ከ ቤተሰቦ ጋር መስራት ይችላሉ ሊንኩን በመጫን ይመልከቱ ዶክተርስ ኢትዮጵያ 👇👇👇👇👇 ስፖርት የመስራት ሱስ ይኖር ይሆን በአሁኑ ወቅት ብዙ የስፖርት መስሪያ ቦታዎች ተጨናንቀው ይታያል ስፖርት መስራት ለጤና ጠቃሚ ቢሆንም እንዳንድ ግዜ ግን ከዛ በላይም አልፎ ስፖርት ካልሰራው ዲፕሬሽን ውስጥ ገባለው ሰውነቴ ይበላሻል የሚሉ ሰዎችም አሉ ሱስ ማለት ራስን ለ ሆነ ነገር ተገዢ ማድረግ ነው ስለዚህ ስፖርት መስራት እውነት ሱስ ይሆን 👇👇👇 ሙሉ ቪዲዮውን በ ዮቲውብ ይመልከቱ ስፖርት ቤት ጂም ለሚያበዙ ሁሉ ሼር ያድርጉ 👇👇👇 ድንገተኛ አደጋ የአጥንት ስብራት አያርገውና ድንገተኛ የሆነ አደጋ ቢደርስቦ ምን ማድረግ እንዳለቦ ያቃሉ በሃገራችን የመኪና አደጋ በ ከፍተኛ ደረጃ አየጨመረ እና የብዙ ሰዎችን ሂወት እየቀጠፈም ይገኛል ። በሃገራችን ያለውም ወቅታዊ ሁኔታም ጦርነቶች ብዙ ሰዎችን ለ ድንገተኛ የሆነ አደጋዎች ስብራቶች ያጋልጣል። ዶር ቃልቂዳን አጥንት ስፔሻሊስት ሃኪም ስለ ድንገተኛ አደጋ እና ስብራቶች አብራርቶልናል እርሶም ይህ ችግር ቢደርስቦ ማድረግ ያለቦትን ነገር ቀድመው ይወቁ ዶክተርስ ኢትዮጵያ በ አዳዲስ ፕሮግራሞችና የናንተን ጥያቄዎች በሶሻል ሚዲያ መልስ የሚያገኙበትን መንገድ እያስተካከልን ሲሆን ከ ትንሽ የ እረፍት ግዜያት በኋላ በ ቴሌቪዥን ፕሮግማችን በ ፋና ቴሌቪዥን ያገኙናል ከታች ያለውን በመጫን ይመልከቱ 👇👇👇👇👇👇👇 ከትንሽ ግዚያት በፊት ስፖርት መስራት እንደ ቅንጦት ይታይ ነበር አሁን ላይ ግን በ ስፖርት መስራያ ቦታዎች ላይ ብዙዎች ሲሰሩ ይታያል ይህንንም ተከትሎ ስፖርት ማወቅ ያለብን በጣም አስፈላጊ ነገር አለ ብዙ ሰው አንድ አመት ያህል ሰርቻለው ለውጥ ምንም የለኝም ስፖርት ጥቅም የለውም ይላል እኛ ምን መስራት እንዳለቦት ሚስጥሩን እንንገሮት ከዚ በኋላ ጊዜዎን ሳያባክኑ በአጭር ግዜ ውስጥ ለውጦን ያያሉ። በዚህ ዮቲውብ ቪዲዮ ላይ ምን መስራት እንዳለቦት ለ ጀማሪ እንዲሁም በመስራት ላይ ላላቹ አጭር ቪዲዮ ይመልከቱ 👇👇👇👇👇👇 ልጆች ላላችሁ አባት እናት ወይንም እህት ወንድም በቅርቡ ልጅ ለመውለድ የምታስቡ ባሁኑ ሰአት እርግዝና ላይ ላላችሁ ። ልጆች አንዳንድ ግዜ ምግብ አልመገብ ይላሉ ይህ ደግሞ ለወላጅ በጣም አስጨናቂ ነገር ነው ህፃናት ምግብ አልመገብ የሚሉት በምን ምክንያት ይሆን ህፃናት ከተወለዱ 1 ሰዐት ጀምሮ የእናት ጡት ወተትን ማግኘት አለባቸው የእናት ጡት ወተትን የሚወስዱ ልጆች ወደፊት የመወፈር እድላቸው በበሽታ የመጠቃት እድላቸው አነስተኛ ነው ። ህፃናት ስድስት ወር ሲሞላቸው ተጨማሪ ምግብ መመገብ ሲፈልጉ አንዳንድ ምልክቶችን ያሳያሉ። ህፃናት የምግብ መመገብ ፍላጎታቸው ለምን ይቀንሳል ዶር ኤልሳቤጥ ለዚህ መልስ ይህን ትለናለች በ ዮቲውብ ቻናላችን ላይ የ ዶርን ስልክ ያስቀመጥን ሲሆን በ ግል ለማማከር መደወል ትችላላችሁ ። 👇👇👇👇 በብዙ ማህበራዊ ሚዲያዎች በ ከፋተኛ ሁኔታ እየተሸጠ ያለው ፕሮቲን ክሬቲን ፖውደሮች እና ሌሎች ያወፍራል ተብለው የሚሸጡ ፓውደሮች እውነት ጥቅም አላቸው ወይ ምን አልባት ለልጆ መግዛት አስበው ይሆናል ወይም ባሁኑ ሰአት ገዝተው እየተጠቀሙም ይሆናል ወይንም ደግሞ ለመግዛት አስበው የትኛው ፖውደር ልጠቀም እያሉ ነው በዚህ ቪዲዮ ሙሉ መልሱን መልሰናል ሁሉም ሰው መውሰድ ይችላል ወይ እድሜስ ገደብ አለው ወይ ለ ኩላሊት ህመምስ ያጋልጣል ወይ ውሃ በደንብ ጠጡ ለምን ተባለ እነዚህን ዋና ነገሮች ላይ መልስ ሰጠናል አሁኑኑ ይመልከቱ እርሶ ባይጠቀሙ ሌላ ቤተሰቦ ሊጠቀም ስለሚችል ሼር በማድረግ ለሁሉም ሰው እናድርስ ከዚህ በፊት እነዚህን ፓውደሮች የሚጠቀሙ ከሆነ ልምዶን በ ዮቲውብ ኮሜንት ላይ ያስቀምጡልን 👇👇👇👇👇👇👇👇👇👇👇👇👇👇 ተጭነው ይመልከቱ nan nan nan ዛሬ ምሽት 330 በ ፋና ቴሌቪዥን ስለ ፕሮቲን ክሬቲን ፓውደሮች ምን ማወቅ ይፈልጋሉ ባሁኑ ሰአት በ ማህበራዊ ሚዲያ በ ከፋተኛ ሁኔታ እየተሸጡ የሚገኙ እነዚህ ፖውደሮች እውነት ለ ኩላሊት ህመም ያጋልጣሉ ወይ በተጨማሪም እቤቶ ሆነው እነዚህን እንቅስቃሴዎች በማድረግ ጤናዎን ይጠብቁ። ስፖርት ሱስ ይሆናል ወይ መልሱን በ ፋና ቴሌቪዥን ይጠብቁን። 330 በ ፋና ቴሌቪዥን ከሳምንት በፊት በለቀቅነው ቦርጭን በህክምና እንዴት ማጥፋት ይቻላል በሚለው ርእሳችን ከ 100000 በላይ እይታን አግኝቷል ። ስለሆነም ቦርጭን ከምናጠፋበት ዋና መንገዶች ዋና አማራጭ የሆነው ስፖርታዊ እንቅስቃሴ ሲሆን እቤት ውስጥ ሆነን እነዚህን ቀለል ያሉ ስፖርታዊ እንቅስቃሴዎችን በማድረግ ቦርጭን ማጥፋት ይችላሉ አሁን በ ዮቲውብ ቻናላችን በመሄድ ISSA certified personal Trainer ትንሳይ ብርሃኑ ጋር ቆይታ አድርገናል። በቀላሉ  ...
